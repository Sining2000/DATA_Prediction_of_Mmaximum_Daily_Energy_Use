# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
price_and_demand = pd.read_csv("price_and_demand.csv")
price_and_demand
# Out:
#      REGION    SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE
# 0      VIC1    1/11/2022 0:30      4178.18   8.94      TRADE
# 1      VIC1    1/11/2022 1:00      4086.02   0.14      TRADE
# 2      VIC1    1/11/2022 1:30      4033.37   0.02      TRADE
# 3      VIC1    1/11/2022 2:00      3985.64   0.00      TRADE
# 4      VIC1    1/11/2022 2:30      3885.64   0.02      TRADE
# ...     ...               ...          ...    ...        ...
# 8347   VIC1  23/04/2023 22:00      4717.55  84.09      TRADE
# 8348   VIC1  23/04/2023 22:30      4520.39  81.25      TRADE
# 8349   VIC1  23/04/2023 23:00      4472.49  93.97      TRADE
# 8350   VIC1  23/04/2023 23:30      4621.36  83.96      TRADE
# 8351   VIC1   24/04/2023 0:00      4395.96  63.77      TRADE
#
# [8352 rows x 5 columns]

# %%
# Check datatype of the dataframe
price_and_demand.dtypes
# Out:
# REGION             object
# SETTLEMENTDATE     object
# TOTALDEMAND       float64
# RRP               float64
# PERIODTYPE         object
# dtype: object

# %%
# check if there is any mising data
price_and_demand.isna().sum()
# Out:
# REGION            0
# SETTLEMENTDATE    0
# TOTALDEMAND       0
# RRP               0
# PERIODTYPE        0
# dtype: int64

# %%
# Convert "SETTLEMENTDATE" column to datetime
price_and_demand["SETTLEMENTDATE"] = pd.to_datetime(price_and_demand["SETTLEMENTDATE"], format="%d/%m/%Y %H:%M")

# %%
# Extract date from "SETTLEMENTDATE" and create a new 'Date' column
price_and_demand['Date'] = price_and_demand['SETTLEMENTDATE'].dt.date

# %%
# Sampling 20 examples
price_and_demand.sample(20)
# Out:
#      REGION      SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE        Date
# 2049   VIC1 2022-12-13 17:00:00      4510.26  -38.00      TRADE  2022-12-13
# 3405   VIC1 2023-01-10 23:00:00      4542.60   88.52      TRADE  2023-01-10
# 1706   VIC1 2022-12-06 13:30:00      3557.42   71.86      TRADE  2022-12-06
# 173    VIC1 2022-11-04 15:00:00      3708.47   36.34      TRADE  2022-11-04
# 6083   VIC1 2023-03-07 18:00:00      5078.52    8.94      TRADE  2023-03-07
# 7928   VIC1 2023-04-15 04:30:00      3414.64  -49.40      TRADE  2023-04-15
# 267    VIC1 2022-11-06 14:00:00      2963.63   28.96      TRADE  2022-11-06
# 3085   VIC1 2023-01-04 07:00:00      4174.97  -38.00      TRADE  2023-01-04
# 6497   VIC1 2023-03-16 09:00:00      4494.18  -25.12      TRADE  2023-03-16
# 5275   VIC1 2023-02-18 22:00:00      4556.38  105.00      TRADE  2023-02-18
# 8255   VIC1 2023-04-22 00:00:00      4662.14  135.86      TRADE  2023-04-22
# 1555   VIC1 2022-12-03 10:00:00      3329.96  -45.09      TRADE  2022-12-03
# 1653   VIC1 2022-12-05 11:00:00      4130.13  -51.20      TRADE  2022-12-05
# 8139   VIC1 2023-04-19 14:00:00      4046.68   -8.23      TRADE  2023-04-19
# 2480   VIC1 2022-12-22 16:30:00      5398.74   19.13      TRADE  2022-12-22
# 351    VIC1 2022-11-08 08:00:00      4383.63   19.13      TRADE  2022-11-08
# 5255   VIC1 2023-02-18 12:00:00      3100.15  -50.01      TRADE  2023-02-18
# 249    VIC1 2022-11-06 05:00:00      3566.42   77.89      TRADE  2022-11-06
# 466    VIC1 2022-11-10 17:30:00      5364.76  117.78      TRADE  2022-11-10
# 2765   VIC1 2022-12-28 15:00:00      4692.18    9.00      TRADE  2022-12-28

# %%
# Calculate maximum daily energy demand and average rrp
max_demand = price_and_demand.groupby("Date")['TOTALDEMAND'].max()
print(max_demand)

mean_rrp = price_and_demand.groupby("Date")['RRP'].mean().round(2)
# Out:
# Date
# 2022-11-01    5627.52
# 2022-11-02    6018.43
# 2022-11-03    6004.84
# 2022-11-04    5757.62
# 2022-11-05    4783.60
#                ...
# 2023-04-20    6084.21
# 2023-04-21    5903.60
# 2023-04-22    5313.61
# 2023-04-23    5361.47
# 2023-04-24    4395.96
# Name: TOTALDEMAND, Length: 175, dtype: float64

# %%
mean_rrp
# Out:
# Date
# 2022-11-01     -3.76
# 2022-11-02     -2.52
# 2022-11-03     63.21
# 2022-11-04    110.94
# 2022-11-05     72.96
#                ...
# 2023-04-20    130.71
# 2023-04-21    131.46
# 2023-04-22     80.39
# 2023-04-23     63.21
# 2023-04-24     63.77
# Name: RRP, Length: 175, dtype: float64

# %%
# Importing Weather Dataset
weather = pd.read_csv("weather.csv", encoding='latin-1',dayfirst = True)
weather
# Out:
#                                Location        Date  Minimum temperature (°C)  \
# 0    Melbourne (Olympic Park), Victoria   1/11/2022                       8.5
# 1    Melbourne (Olympic Park), Victoria   2/11/2022                       6.9
# 2    Melbourne (Olympic Park), Victoria   3/11/2022                       9.1
# 3    Melbourne (Olympic Park), Victoria   4/11/2022                      10.2
# 4    Melbourne (Olympic Park), Victoria   5/11/2022                      11.8
# ..                                  ...         ...                       ...
# 170  Melbourne (Olympic Park), Victoria  20/04/2023                       7.8
# 171  Melbourne (Olympic Park), Victoria  21/04/2023                      11.3
# 172  Melbourne (Olympic Park), Victoria  22/04/2023                      14.6
# 173  Melbourne (Olympic Park), Victoria  23/04/2023                      14.8
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                        13.3            3.0               NaN
# 1                        15.7            2.8               NaN
# 2                        15.4            0.4               NaN
# 3                        17.8            0.2               NaN
# 4                        22.7            0.0               NaN
# ..                        ...            ...               ...
# 170                      18.5            0.0               NaN
# 171                      19.0            0.0               NaN
# 172                      19.2            0.0               NaN
# 173                      19.0            0.0               NaN
# 174                       NaN            0.0               NaN
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 0                 NaN                              SW
# 1                 NaN                             SSW
# 2                 NaN                             SSW
# 3                 NaN                               S
# 4                 NaN                               N
# ..                ...                             ...
# 170               NaN                             SSW
# 171               NaN                             SSW
# 172               NaN                             SSW
# 173               NaN                             SSW
# 174               NaN                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                                 44.0                     11:36  ...
# 1                                 43.0                     11:33  ...
# 2                                 31.0                      8:07  ...
# 3                                 24.0                     14:50  ...
# 4                                 31.0                     11:58  ...
# ..                                 ...                       ...  ...
# 170                               17.0                     12:47  ...
# 171                               13.0                     10:48  ...
# 172                               22.0                     16:09  ...
# 173                               26.0                     15:45  ...
# 174                                NaN                       NaN  ...
#
#      9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                         NaN                  NW                     13
# 1                         NaN                   W                      9
# 2                         NaN                 SSW                      9
# 3                         NaN                 WSW                      6
# 4                         NaN                   N                      9
# ..                        ...                 ...                    ...
# 170                       NaN                 NNE                      7
# 171                       NaN                  NE                      6
# 172                       NaN                  SW                      6
# 173                       NaN                 SSE                      7
# 174                       NaN                  NE                      9
#
#     9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                    991.3                 13.2                       59.0
# 1                   1006.7                 15.1                       54.0
# 2                   1019.2                 13.8                       67.0
# 3                   1028.1                 16.9                       56.0
# 4                   1026.3                 18.8                       65.0
# ..                     ...                  ...                        ...
# 170                 1026.8                 17.5                       58.0
# 171                 1030.5                 18.6                       64.0
# 172                 1031.9                 18.8                       64.0
# 173                 1034.4                 17.8                       71.0
# 174                 1032.5                  NaN                        NaN
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                         NaN                 WNW                   11.0
# 1                         NaN                 SSW                   13.0
# 2                         NaN                 SSW                    9.0
# 3                         NaN                  SW                    9.0
# 4                         NaN                  SW                   11.0
# ..                        ...                 ...                    ...
# 170                       NaN                  SW                    4.0
# 171                       NaN                 SSE                    2.0
# 172                       NaN                 SSW                   11.0
# 173                       NaN                 SSW                   13.0
# 174                       NaN                 NaN                    NaN
#
#     3pm MSL pressure (hPa)
# 0                    991.5
# 1                   1008.4
# 2                   1021.3
# 3                   1026.6
# 4                   1023.2
# ..                     ...
# 170                 1025.5
# 171                 1029.2
# 172                 1029.7
# 173                 1032.4
# 174                    NaN
#
# [175 rows x 22 columns]

# %%
weather.dtypes
# Out:
# Location                              object
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Evaporation (mm)                     float64
# Sunshine (hours)                     float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am cloud amount (oktas)             float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm cloud amount (oktas)             float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
#Removing entirely empty columns
weather = weather.dropna(axis = 1, how = 'all')
weather
# Out:
#                                Location        Date  Minimum temperature (°C)  \
# 0    Melbourne (Olympic Park), Victoria   1/11/2022                       8.5
# 1    Melbourne (Olympic Park), Victoria   2/11/2022                       6.9
# 2    Melbourne (Olympic Park), Victoria   3/11/2022                       9.1
# 3    Melbourne (Olympic Park), Victoria   4/11/2022                      10.2
# 4    Melbourne (Olympic Park), Victoria   5/11/2022                      11.8
# ..                                  ...         ...                       ...
# 170  Melbourne (Olympic Park), Victoria  20/04/2023                       7.8
# 171  Melbourne (Olympic Park), Victoria  21/04/2023                      11.3
# 172  Melbourne (Olympic Park), Victoria  22/04/2023                      14.6
# 173  Melbourne (Olympic Park), Victoria  23/04/2023                      14.8
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm) Direction of maximum wind gust   \
# 0                        13.3            3.0                              SW
# 1                        15.7            2.8                             SSW
# 2                        15.4            0.4                             SSW
# 3                        17.8            0.2                               S
# 4                        22.7            0.0                               N
# ..                        ...            ...                             ...
# 170                      18.5            0.0                             SSW
# 171                      19.0            0.0                             SSW
# 172                      19.2            0.0                             SSW
# 173                      19.0            0.0                             SSW
# 174                       NaN            0.0                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 0                                 44.0                     11:36
# 1                                 43.0                     11:33
# 2                                 31.0                      8:07
# 3                                 24.0                     14:50
# 4                                 31.0                     11:58
# ..                                 ...                       ...
# 170                               17.0                     12:47
# 171                               13.0                     10:48
# 172                               22.0                     16:09
# 173                               26.0                     15:45
# 174                                NaN                       NaN
#
#      9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 0                    12.0                         64                 NW
# 1                    11.0                         65                  W
# 2                    11.5                         70                SSW
# 3                    12.3                         84                WSW
# 4                    14.0                         78                  N
# ..                    ...                        ...                ...
# 170                  12.4                         72                NNE
# 171                  14.8                         78                 NE
# 172                  15.2                         84                 SW
# 173                  16.7                         79                SSE
# 174                  14.3                         87                 NE
#
#     9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                      13                   991.3                  13.2
# 1                       9                  1006.7                  15.1
# 2                       9                  1019.2                  13.8
# 3                       6                  1028.1                  16.9
# 4                       9                  1026.3                  18.8
# ..                    ...                     ...                   ...
# 170                     7                  1026.8                  17.5
# 171                     6                  1030.5                  18.6
# 172                     6                  1031.9                  18.8
# 173                     7                  1034.4                  17.8
# 174                     9                  1032.5                   NaN
#
#      3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         59.0                WNW                   11.0
# 1                         54.0                SSW                   13.0
# 2                         67.0                SSW                    9.0
# 3                         56.0                 SW                    9.0
# 4                         65.0                 SW                   11.0
# ..                         ...                ...                    ...
# 170                       58.0                 SW                    4.0
# 171                       64.0                SSE                    2.0
# 172                       64.0                SSW                   11.0
# 173                       71.0                SSW                   13.0
# 174                        NaN                NaN                    NaN
#
#      3pm MSL pressure (hPa)
# 0                     991.5
# 1                    1008.4
# 2                    1021.3
# 3                    1026.6
# 4                    1023.2
# ..                      ...
# 170                  1025.5
# 171                  1029.2
# 172                  1029.7
# 173                  1032.4
# 174                     NaN
#
# [175 rows x 18 columns]

# %%
#Setting Date format to match
weather["Date"] = pd.to_datetime(weather['Date'], format="%d/%m/%Y")
weather.head()

#Setting Date as the ID Column
weather = weather.set_index('Date')
weather
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2022-11-04  Melbourne (Olympic Park), Victoria                      10.2
# 2022-11-05  Melbourne (Olympic Park), Victoria                      11.8
# ...                                        ...                       ...
# 2023-04-20  Melbourne (Olympic Park), Victoria                       7.8
# 2023-04-21  Melbourne (Olympic Park), Victoria                      11.3
# 2023-04-22  Melbourne (Olympic Park), Victoria                      14.6
# 2023-04-23  Melbourne (Olympic Park), Victoria                      14.8
# 2023-04-24  Melbourne (Olympic Park), Victoria                      11.0
#
#             Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                      13.3            3.0
# 2022-11-02                      15.7            2.8
# 2022-11-03                      15.4            0.4
# 2022-11-04                      17.8            0.2
# 2022-11-05                      22.7            0.0
# ...                              ...            ...
# 2023-04-20                      18.5            0.0
# 2023-04-21                      19.0            0.0
# 2023-04-22                      19.2            0.0
# 2023-04-23                      19.0            0.0
# 2023-04-24                       NaN            0.0
#
#            Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01                              SW                               44.0
# 2022-11-02                             SSW                               43.0
# 2022-11-03                             SSW                               31.0
# 2022-11-04                               S                               24.0
# 2022-11-05                               N                               31.0
# ...                                    ...                                ...
# 2023-04-20                             SSW                               17.0
# 2023-04-21                             SSW                               13.0
# 2023-04-22                             SSW                               22.0
# 2023-04-23                             SSW                               26.0
# 2023-04-24                             NaN                                NaN
#
#            Time of maximum wind gust  9am Temperature (°C)  \
# Date
# 2022-11-01                     11:36                  12.0
# 2022-11-02                     11:33                  11.0
# 2022-11-03                      8:07                  11.5
# 2022-11-04                     14:50                  12.3
# 2022-11-05                     11:58                  14.0
# ...                              ...                   ...
# 2023-04-20                     12:47                  12.4
# 2023-04-21                     10:48                  14.8
# 2023-04-22                     16:09                  15.2
# 2023-04-23                     15:45                  16.7
# 2023-04-24                       NaN                  14.3
#
#             9am relative humidity (%) 9am wind direction  \
# Date
# 2022-11-01                         64                 NW
# 2022-11-02                         65                  W
# 2022-11-03                         70                SSW
# 2022-11-04                         84                WSW
# 2022-11-05                         78                  N
# ...                               ...                ...
# 2023-04-20                         72                NNE
# 2023-04-21                         78                 NE
# 2023-04-22                         84                 SW
# 2023-04-23                         79                SSE
# 2023-04-24                         87                 NE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
# 2023-04-24                     9                  1032.5
#
#             3pm Temperature (°C)  3pm relative humidity (%)  \
# Date
# 2022-11-01                  13.2                       59.0
# 2022-11-02                  15.1                       54.0
# 2022-11-03                  13.8                       67.0
# 2022-11-04                  16.9                       56.0
# 2022-11-05                  18.8                       65.0
# ...                          ...                        ...
# 2023-04-20                  17.5                       58.0
# 2023-04-21                  18.6                       64.0
# 2023-04-22                  18.8                       64.0
# 2023-04-23                  17.8                       71.0
# 2023-04-24                   NaN                        NaN
#
#            3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                WNW                   11.0                   991.5
# 2022-11-02                SSW                   13.0                  1008.4
# 2022-11-03                SSW                    9.0                  1021.3
# 2022-11-04                 SW                    9.0                  1026.6
# 2022-11-05                 SW                   11.0                  1023.2
# ...                       ...                    ...                     ...
# 2023-04-20                 SW                    4.0                  1025.5
# 2023-04-21                SSE                    2.0                  1029.2
# 2023-04-22                SSW                   11.0                  1029.7
# 2023-04-23                SSW                   13.0                  1032.4
# 2023-04-24                NaN                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
# weather.index = pd.to_datetime(weather.index,dayfirst = False).strftime("%Y-%m-%d")

# %%
"""Data Cleaning across entire dataframe"""
#Replacing all occurrences of 'Calm' windspeed with 0 km/h
weather_nocalm = weather.replace("Calm",0)
weather_nocalm
# Out:
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2022-11-04  Melbourne (Olympic Park), Victoria                      10.2
# 2022-11-05  Melbourne (Olympic Park), Victoria                      11.8
# ...                                        ...                       ...
# 2023-04-20  Melbourne (Olympic Park), Victoria                       7.8
# 2023-04-21  Melbourne (Olympic Park), Victoria                      11.3
# 2023-04-22  Melbourne (Olympic Park), Victoria                      14.6
# 2023-04-23  Melbourne (Olympic Park), Victoria                      14.8
# 2023-04-24  Melbourne (Olympic Park), Victoria                      11.0
#
#             Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                      13.3            3.0
# 2022-11-02                      15.7            2.8
# 2022-11-03                      15.4            0.4
# 2022-11-04                      17.8            0.2
# 2022-11-05                      22.7            0.0
# ...                              ...            ...
# 2023-04-20                      18.5            0.0
# 2023-04-21                      19.0            0.0
# 2023-04-22                      19.2            0.0
# 2023-04-23                      19.0            0.0
# 2023-04-24                       NaN            0.0
#
#            Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01                              SW                               44.0
# 2022-11-02                             SSW                               43.0
# 2022-11-03                             SSW                               31.0
# 2022-11-04                               S                               24.0
# 2022-11-05                               N                               31.0
# ...                                    ...                                ...
# 2023-04-20                             SSW                               17.0
# 2023-04-21                             SSW                               13.0
# 2023-04-22                             SSW                               22.0
# 2023-04-23                             SSW                               26.0
# 2023-04-24                             NaN                                NaN
#
#            Time of maximum wind gust  9am Temperature (°C)  \
# Date
# 2022-11-01                     11:36                  12.0
# 2022-11-02                     11:33                  11.0
# 2022-11-03                      8:07                  11.5
# 2022-11-04                     14:50                  12.3
# 2022-11-05                     11:58                  14.0
# ...                              ...                   ...
# 2023-04-20                     12:47                  12.4
# 2023-04-21                     10:48                  14.8
# 2023-04-22                     16:09                  15.2
# 2023-04-23                     15:45                  16.7
# 2023-04-24                       NaN                  14.3
#
#             9am relative humidity (%) 9am wind direction  \
# Date
# 2022-11-01                         64                 NW
# 2022-11-02                         65                  W
# 2022-11-03                         70                SSW
# 2022-11-04                         84                WSW
# 2022-11-05                         78                  N
# ...                               ...                ...
# 2023-04-20                         72                NNE
# 2023-04-21                         78                 NE
# 2023-04-22                         84                 SW
# 2023-04-23                         79                SSE
# 2023-04-24                         87                 NE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
# 2023-04-24                     9                  1032.5
#
#             3pm Temperature (°C)  3pm relative humidity (%)  \
# Date
# 2022-11-01                  13.2                       59.0
# 2022-11-02                  15.1                       54.0
# 2022-11-03                  13.8                       67.0
# 2022-11-04                  16.9                       56.0
# 2022-11-05                  18.8                       65.0
# ...                          ...                        ...
# 2023-04-20                  17.5                       58.0
# 2023-04-21                  18.6                       64.0
# 2023-04-22                  18.8                       64.0
# 2023-04-23                  17.8                       71.0
# 2023-04-24                   NaN                        NaN
#
#            3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                WNW                   11.0                   991.5
# 2022-11-02                SSW                   13.0                  1008.4
# 2022-11-03                SSW                    9.0                  1021.3
# 2022-11-04                 SW                    9.0                  1026.6
# 2022-11-05                 SW                   11.0                  1023.2
# ...                       ...                    ...                     ...
# 2023-04-20                 SW                    4.0                  1025.5
# 2023-04-21                SSE                    2.0                  1029.2
# 2023-04-22                SSW                   11.0                  1029.7
# 2023-04-23                SSW                   13.0                  1032.4
# 2023-04-24                NaN                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
#Replacing all wind directions with True Bearing quantities
weather_bearings = weather_nocalm.replace(['N','NNE','NE','ENE','E','ESE','SE','SSE','S','SSW','SW','WSW','W','WNW','NW','NNW'],
                                          [0,22.5,45,67.5,90,112.5,135,157.5,180,202.5,225,247.5,270,292.5,315,337.5])
#Renaming Columns with True Bearing Units
weather_bearings.rename(columns = {'Direction of maximum wind gust ':'Direction of maximum wind gust (°T)', '9am wind direction':'9am wind direction (°T)','3pm wind direction':'3pm wind direction (°T)'},inplace = True)

#Data Cleaning Complete
processed_data = weather_bearings

processed_data
# Out:
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2022-11-04  Melbourne (Olympic Park), Victoria                      10.2
# 2022-11-05  Melbourne (Olympic Park), Victoria                      11.8
# ...                                        ...                       ...
# 2023-04-20  Melbourne (Olympic Park), Victoria                       7.8
# 2023-04-21  Melbourne (Olympic Park), Victoria                      11.3
# 2023-04-22  Melbourne (Olympic Park), Victoria                      14.6
# 2023-04-23  Melbourne (Olympic Park), Victoria                      14.8
# 2023-04-24  Melbourne (Olympic Park), Victoria                      11.0
#
#             Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                      13.3            3.0
# 2022-11-02                      15.7            2.8
# 2022-11-03                      15.4            0.4
# 2022-11-04                      17.8            0.2
# 2022-11-05                      22.7            0.0
# ...                              ...            ...
# 2023-04-20                      18.5            0.0
# 2023-04-21                      19.0            0.0
# 2023-04-22                      19.2            0.0
# 2023-04-23                      19.0            0.0
# 2023-04-24                       NaN            0.0
#
#             Direction of maximum wind gust (°T)  \
# Date
# 2022-11-01                                225.0
# 2022-11-02                                202.5
# 2022-11-03                                202.5
# 2022-11-04                                180.0
# 2022-11-05                                  0.0
# ...                                         ...
# 2023-04-20                                202.5
# 2023-04-21                                202.5
# 2023-04-22                                202.5
# 2023-04-23                                202.5
# 2023-04-24                                  NaN
#
#             Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# Date
# 2022-11-01                               44.0                     11:36
# 2022-11-02                               43.0                     11:33
# 2022-11-03                               31.0                      8:07
# 2022-11-04                               24.0                     14:50
# 2022-11-05                               31.0                     11:58
# ...                                       ...                       ...
# 2023-04-20                               17.0                     12:47
# 2023-04-21                               13.0                     10:48
# 2023-04-22                               22.0                     16:09
# 2023-04-23                               26.0                     15:45
# 2023-04-24                                NaN                       NaN
#
#             9am Temperature (°C)  9am relative humidity (%)  \
# Date
# 2022-11-01                  12.0                         64
# 2022-11-02                  11.0                         65
# 2022-11-03                  11.5                         70
# 2022-11-04                  12.3                         84
# 2022-11-05                  14.0                         78
# ...                          ...                        ...
# 2023-04-20                  12.4                         72
# 2023-04-21                  14.8                         78
# 2023-04-22                  15.2                         84
# 2023-04-23                  16.7                         79
# 2023-04-24                  14.3                         87
#
#            9am wind direction (°T) 9am wind speed (km/h)  \
# Date
# 2022-11-01                     315                    13
# 2022-11-02                     270                     9
# 2022-11-03                   202.5                     9
# 2022-11-04                   247.5                     6
# 2022-11-05                       0                     9
# ...                            ...                   ...
# 2023-04-20                    22.5                     7
# 2023-04-21                      45                     6
# 2023-04-22                     225                     6
# 2023-04-23                   157.5                     7
# 2023-04-24                      45                     9
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 2022-11-01                   991.3                  13.2
# 2022-11-02                  1006.7                  15.1
# 2022-11-03                  1019.2                  13.8
# 2022-11-04                  1028.1                  16.9
# 2022-11-05                  1026.3                  18.8
# ...                            ...                   ...
# 2023-04-20                  1026.8                  17.5
# 2023-04-21                  1030.5                  18.6
# 2023-04-22                  1031.9                  18.8
# 2023-04-23                  1034.4                  17.8
# 2023-04-24                  1032.5                   NaN
#
#             3pm relative humidity (%)  3pm wind direction (°T)  \
# Date
# 2022-11-01                       59.0                    292.5
# 2022-11-02                       54.0                    202.5
# 2022-11-03                       67.0                    202.5
# 2022-11-04                       56.0                    225.0
# 2022-11-05                       65.0                    225.0
# ...                               ...                      ...
# 2023-04-20                       58.0                    225.0
# 2023-04-21                       64.0                    157.5
# 2023-04-22                       64.0                    202.5
# 2023-04-23                       71.0                    202.5
# 2023-04-24                        NaN                      NaN
#
#             3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                   11.0                   991.5
# 2022-11-02                   13.0                  1008.4
# 2022-11-03                    9.0                  1021.3
# 2022-11-04                    9.0                  1026.6
# 2022-11-05                   11.0                  1023.2
# ...                           ...                     ...
# 2023-04-20                    4.0                  1025.5
# 2023-04-21                    2.0                  1029.2
# 2023-04-22                   11.0                  1029.7
# 2023-04-23                   13.0                  1032.4
# 2023-04-24                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
#Selecting key features based on 'expert' insight and desired focus variables
selected_features = ["Minimum temperature (°C)", "Maximum temperature (°C)", "9am relative humidity (%)","3pm relative humidity (%)","Rainfall (mm)", "Speed of maximum wind gust (km/h)", "9am wind speed (km/h)", "9am MSL pressure (hPa)", "3pm MSL pressure (hPa)"]
# selected_features = ["Maximum temperature (°C)", "3pm relative humidity (%)"]
selected_features

selected_data = processed_data[selected_features]

#Checking for missing values across selected features
missing_value = processed_data[selected_features].isnull()
missing_value

#Removing data points with missing selected features
selected_data = processed_data[selected_features].dropna()
predictor_data = processed_data[selected_features].dropna()
predictor_data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  \
# Date
# 2022-11-01                       8.5                      13.3
# 2022-11-02                       6.9                      15.7
# 2022-11-03                       9.1                      15.4
# 2022-11-04                      10.2                      17.8
# 2022-11-05                      11.8                      22.7
# ...                              ...                       ...
# 2023-04-19                      14.4                      17.5
# 2023-04-20                       7.8                      18.5
# 2023-04-21                      11.3                      19.0
# 2023-04-22                      14.6                      19.2
# 2023-04-23                      14.8                      19.0
#
#             9am relative humidity (%)  3pm relative humidity (%)  \
# Date
# 2022-11-01                         64                       59.0
# 2022-11-02                         65                       54.0
# 2022-11-03                         70                       67.0
# 2022-11-04                         84                       56.0
# 2022-11-05                         78                       65.0
# ...                               ...                        ...
# 2023-04-19                         66                       53.0
# 2023-04-20                         72                       58.0
# 2023-04-21                         78                       64.0
# 2023-04-22                         84                       64.0
# 2023-04-23                         79                       71.0
#
#             Rainfall (mm)  Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01            3.0                               44.0
# 2022-11-02            2.8                               43.0
# 2022-11-03            0.4                               31.0
# 2022-11-04            0.2                               24.0
# 2022-11-05            0.0                               31.0
# ...                   ...                                ...
# 2023-04-19            1.2                               28.0
# 2023-04-20            0.0                               17.0
# 2023-04-21            0.0                               13.0
# 2023-04-22            0.0                               22.0
# 2023-04-23            0.0                               26.0
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-19                     9                  1022.0
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
#
#             3pm MSL pressure (hPa)
# Date
# 2022-11-01                   991.5
# 2022-11-02                  1008.4
# 2022-11-03                  1021.3
# 2022-11-04                  1026.6
# 2022-11-05                  1023.2
# ...                            ...
# 2023-04-19                  1022.1
# 2023-04-20                  1025.5
# 2023-04-21                  1029.2
# 2023-04-22                  1029.7
# 2023-04-23                  1032.4
#
# [174 rows x 9 columns]

# %%
# Introducing Target Variables
selected_data["Average RRP"] = mean_rrp
selected_data["Maximum Energy Demand"] = max_demand
selected_data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  \
# Date
# 2022-11-01                       8.5                      13.3
# 2022-11-02                       6.9                      15.7
# 2022-11-03                       9.1                      15.4
# 2022-11-04                      10.2                      17.8
# 2022-11-05                      11.8                      22.7
# ...                              ...                       ...
# 2023-04-19                      14.4                      17.5
# 2023-04-20                       7.8                      18.5
# 2023-04-21                      11.3                      19.0
# 2023-04-22                      14.6                      19.2
# 2023-04-23                      14.8                      19.0
#
#             9am relative humidity (%)  3pm relative humidity (%)  \
# Date
# 2022-11-01                         64                       59.0
# 2022-11-02                         65                       54.0
# 2022-11-03                         70                       67.0
# 2022-11-04                         84                       56.0
# 2022-11-05                         78                       65.0
# ...                               ...                        ...
# 2023-04-19                         66                       53.0
# 2023-04-20                         72                       58.0
# 2023-04-21                         78                       64.0
# 2023-04-22                         84                       64.0
# 2023-04-23                         79                       71.0
#
#             Rainfall (mm)  Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01            3.0                               44.0
# 2022-11-02            2.8                               43.0
# 2022-11-03            0.4                               31.0
# 2022-11-04            0.2                               24.0
# 2022-11-05            0.0                               31.0
# ...                   ...                                ...
# 2023-04-19            1.2                               28.0
# 2023-04-20            0.0                               17.0
# 2023-04-21            0.0                               13.0
# 2023-04-22            0.0                               22.0
# 2023-04-23            0.0                               26.0
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-19                     9                  1022.0
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
# ...                            ...          ...                    ...
# 2023-04-19                  1022.1       102.33                6042.88
# 2023-04-20                  1025.5       130.71                6084.21
# 2023-04-21                  1029.2       131.46                5903.60
# 2023-04-22                  1029.7        80.39                5313.61
# 2023-04-23                  1032.4        63.21                5361.47
#
# [174 rows x 11 columns]

# %%
plot_x1 = "Minimum temperature (°C)"
plot_y1 = "Maximum Energy Demand"

plt.scatter(selected_data[plot_x1], selected_data[plot_y1], label="Data Points", color="blue")
plt.xlabel(plot_x1)
plt.ylabel(plot_y1)
plt.title(''.join([plot_x1," vs ",plot_y1]))
plt.show()

plot_x2 = "Maximum temperature (°C)"
plot_y2 = "Maximum Energy Demand"

plt.scatter(selected_data[plot_x2], selected_data[plot_y2], label="Data Points", color="blue")
plt.xlabel(plot_x2)
plt.ylabel(plot_y2)
plt.title(''.join([plot_x2," vs ",plot_y2]))
plt.show()

plot_x3 = "3pm relative humidity (%)"
plot_y3 = "Maximum temperature (°C)"

plt.scatter(selected_data[plot_x3], selected_data[plot_y3], label="Data Points", color="green")
plt.xlabel(plot_x3)
plt.ylabel(plot_y3)
plt.title(''.join([plot_x3," vs ",plot_y3]))
plt.show()

plot_x5 = "Speed of maximum wind gust (km/h)"
plot_y5 = "Average RRP"

plt.scatter(selected_data[plot_x5], selected_data[plot_y5], label="Data Points", color="red")
plt.xlabel(plot_x5)
plt.ylabel(plot_y5)
plt.title(''.join([plot_x5," vs ",plot_y5]))
plt.show()

plot_x6 = "Speed of maximum wind gust (km/h)"
plot_y6 = "Maximum Energy Demand"

plt.scatter(selected_data[plot_x6], selected_data[plot_y6], label="Data Points", color="red")
plt.xlabel(plot_x6)
plt.ylabel(plot_y6)
plt.title(''.join([plot_x6," vs ",plot_y6]))
plt.show()

# %%
"""Modelling with Various Methodologies to Predict Energy"""
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn import preprocessing
from sklearn import impute

# %%
#Importing the Cleaned Data to be Analysed
data = predictor_data
data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  \
# Date
# 2022-11-01                       8.5                      13.3
# 2022-11-02                       6.9                      15.7
# 2022-11-03                       9.1                      15.4
# 2022-11-04                      10.2                      17.8
# 2022-11-05                      11.8                      22.7
# ...                              ...                       ...
# 2023-04-19                      14.4                      17.5
# 2023-04-20                       7.8                      18.5
# 2023-04-21                      11.3                      19.0
# 2023-04-22                      14.6                      19.2
# 2023-04-23                      14.8                      19.0
#
#             9am relative humidity (%)  3pm relative humidity (%)  \
# Date
# 2022-11-01                         64                       59.0
# 2022-11-02                         65                       54.0
# 2022-11-03                         70                       67.0
# 2022-11-04                         84                       56.0
# 2022-11-05                         78                       65.0
# ...                               ...                        ...
# 2023-04-19                         66                       53.0
# 2023-04-20                         72                       58.0
# 2023-04-21                         78                       64.0
# 2023-04-22                         84                       64.0
# 2023-04-23                         79                       71.0
#
#             Rainfall (mm)  Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01            3.0                               44.0
# 2022-11-02            2.8                               43.0
# 2022-11-03            0.4                               31.0
# 2022-11-04            0.2                               24.0
# 2022-11-05            0.0                               31.0
# ...                   ...                                ...
# 2023-04-19            1.2                               28.0
# 2023-04-20            0.0                               17.0
# 2023-04-21            0.0                               13.0
# 2023-04-22            0.0                               22.0
# 2023-04-23            0.0                               26.0
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-19                     9                  1022.0
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
#
#             3pm MSL pressure (hPa)
# Date
# 2022-11-01                   991.5
# 2022-11-02                  1008.4
# 2022-11-03                  1021.3
# 2022-11-04                  1026.6
# 2022-11-05                  1023.2
# ...                            ...
# 2023-04-19                  1022.1
# 2023-04-20                  1025.5
# 2023-04-21                  1029.2
# 2023-04-22                  1029.7
# 2023-04-23                  1032.4
#
# [174 rows x 9 columns]

# %%
#Defining Target Variable
nrg_classlabel = selected_data["Maximum Energy Demand"]
nrg_classlabel
# Out:
# Date
# 2022-11-01    5627.52
# 2022-11-02    6018.43
# 2022-11-03    6004.84
# 2022-11-04    5757.62
# 2022-11-05    4783.60
#                ...
# 2023-04-19    6042.88
# 2023-04-20    6084.21
# 2023-04-21    5903.60
# 2023-04-22    5313.61
# 2023-04-23    5361.47
# Name: Maximum Energy Demand, Length: 174, dtype: float64

# %%
# # #Splitting data into training and test sets
nrg_X_train, nrg_X_test, nrg_y_train, nrg_y_test = train_test_split(data, nrg_classlabel, test_size = 0.2, random_state = 42)

# Preprocessing with Standardization with Mean 0, Std 1
scaler = preprocessing.StandardScaler().fit(nrg_X_train)
nrg_X_train = scaler.transform(nrg_X_train)
nrg_X_test = scaler.transform(nrg_X_test)

# Imputing Missing Data with Mean or Average Data
imputer = impute.SimpleImputer().fit(nrg_X_train)
nrg_X_train = imputer.transform(nrg_X_train)
nrg_X_test = imputer.transform(nrg_X_test)

# %%
"""Linear Regression Modeeling"""

#Importing libraries 
from sklearn import linear_model

#Creating the linear regression model
nrg_lm = linear_model.LinearRegression()

#Training the Model
nrg_lm.fit(nrg_X_train, nrg_y_train)

#Making predictions
nrg_y_predlm = nrg_lm.predict(nrg_X_test)

#Evaluating the Model
print(f"R2 Score: ", "{:.3f}".format(r2_score(nrg_y_test, nrg_y_predlm)))
print("RMSE score: ", "{:.3f}".format(mean_squared_error(nrg_y_test, nrg_y_predlm, squared = False)))
# Out:
# R2 Score:  0.188
# RMSE score:  574.836

# %%
"""Decision Tree Regression Modelling"""
#Using a regression model instead of a classification model as Data is Continuous.

#Importing libraries 
from sklearn.tree import DecisionTreeRegressor

#Creating the decision tree regression model
dt = DecisionTreeRegressor()

#Training the Model
dt.fit(nrg_X_train, nrg_y_train)

#Making predictions
nrg_y_preddt = dt.predict(nrg_X_test)

#Evaluating the Model
print(f"R2 Score: ", "{:.3f}".format(r2_score(nrg_y_test, nrg_y_preddt)))
print("RMSE score: ", "{:.3f}".format(mean_squared_error(nrg_y_test, nrg_y_preddt, squared = False)))
# Out:
# R2 Score:  0.537
# RMSE score:  434.004

# %%
"""Modelling with Various Methodologies to Predict Energy Pricing """

# Importing Modelling tools
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn import preprocessing
from sklearn import impute

# %%
#Defining Target Variable
cost_classlabel = selected_data["Average RRP"]
cost_classlabel
# Out:
# Date
# 2022-11-01     -3.76
# 2022-11-02     -2.52
# 2022-11-03     63.21
# 2022-11-04    110.94
# 2022-11-05     72.96
#                ...
# 2023-04-19    102.33
# 2023-04-20    130.71
# 2023-04-21    131.46
# 2023-04-22     80.39
# 2023-04-23     63.21
# Name: Average RRP, Length: 174, dtype: float64

# %%
# # #Splitting data into training and test sets
cost_X_train, cost_X_test, cost_y_train, cost_y_test = train_test_split(data, cost_classlabel, test_size = 0.2, random_state = 42)

# # Preprocessing with Standardization with Mean 0, Std 1
scaler = preprocessing.StandardScaler().fit(cost_X_train)
cost_X_train = scaler.transform(cost_X_train)
cost_X_test = scaler.transform(cost_X_test)

# Imputing Missing Data with Mean or Average Data
imputer = impute.SimpleImputer().fit(cost_X_train)
cost_X_train = imputer.transform(cost_X_train)
cost_X_test = imputer.transform(cost_X_test)

# %%
"""Linear Regression Modeeling"""

#Importing libraries 
from sklearn import linear_model

#Creating the linear regression model
cost_lm = linear_model.LinearRegression()

#Training the Model
cost_lm.fit(cost_X_train, cost_y_train)

#Making predictions
cost_y_predlm = cost_lm.predict(cost_X_test)

#Evaluating the Model
print(f"R2 Score: ", "{:.3f}".format(r2_score(cost_y_test, cost_y_predlm)))
print("RMSE score: ", "{:.3f}".format(mean_squared_error(cost_y_test, cost_y_predlm, squared = False)))
# Out:
# R2 Score:  0.154
# RMSE score:  43.374

# %%
"""Decision Tree Regression Modelling"""
#Using a regression model instead of a classification model as Data is Continuous.

#Importing libraries 
from sklearn.tree import DecisionTreeRegressor

#Creating the decision tree regression model
cost_dt = DecisionTreeRegressor()

#Training the Model
cost_dt.fit(cost_X_train, cost_y_train)

#Making predictions
cost_y_preddt = dt.predict(cost_X_test)

#Evaluating the Model
print(f"R2 Score: ", "{:.3f}".format(r2_score(cost_y_test, cost_y_preddt)))
print("RMSE score: ", "{:.3f}".format(mean_squared_error(cost_y_test, cost_y_preddt, squared = False)))
# Out:
# R2 Score:  -13544.391
# RMSE score:  5489.034
