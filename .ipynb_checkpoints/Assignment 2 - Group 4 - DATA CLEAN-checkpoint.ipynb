# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
price_and_demand = pd.read_csv("price_and_demand.csv")
price_and_demand
# Out:
#      REGION    SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE
# 0      VIC1    1/11/2022 0:30      4178.18   8.94      TRADE
# 1      VIC1    1/11/2022 1:00      4086.02   0.14      TRADE
# 2      VIC1    1/11/2022 1:30      4033.37   0.02      TRADE
# 3      VIC1    1/11/2022 2:00      3985.64   0.00      TRADE
# 4      VIC1    1/11/2022 2:30      3885.64   0.02      TRADE
# ...     ...               ...          ...    ...        ...
# 8347   VIC1  23/04/2023 22:00      4717.55  84.09      TRADE
# 8348   VIC1  23/04/2023 22:30      4520.39  81.25      TRADE
# 8349   VIC1  23/04/2023 23:00      4472.49  93.97      TRADE
# 8350   VIC1  23/04/2023 23:30      4621.36  83.96      TRADE
# 8351   VIC1   24/04/2023 0:00      4395.96  63.77      TRADE
#
# [8352 rows x 5 columns]

# %%
# Check datatype of the dataframe
price_and_demand.dtypes
# Out:
# REGION             object
# SETTLEMENTDATE     object
# TOTALDEMAND       float64
# RRP               float64
# PERIODTYPE         object
# dtype: object

# %%
# check if there is any mising data
price_and_demand.isna().sum()
# Out:
# REGION            0
# SETTLEMENTDATE    0
# TOTALDEMAND       0
# RRP               0
# PERIODTYPE        0
# dtype: int64

# %%
# Convert "SETTLEMENTDATE" column to datetime
price_and_demand["SETTLEMENTDATE"] = pd.to_datetime(price_and_demand["SETTLEMENTDATE"], format="%d/%m/%Y %H:%M")

# %%
# Extract date from "SETTLEMENTDATE" and create a new 'Date' column
price_and_demand['Date'] = price_and_demand['SETTLEMENTDATE'].dt.date

# %%
# Sampling 20 examples
price_and_demand.sample(20)
# Out:
#      REGION      SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE        Date
# 7812   VIC1 2023-04-12 18:30:00      5737.40  144.69      TRADE  2023-04-12
# 1199   VIC1 2022-11-26 00:00:00      4230.43  106.25      TRADE  2022-11-26
# 5992   VIC1 2023-03-05 20:30:00      4790.04  -25.91      TRADE  2023-03-05
# 2620   VIC1 2022-12-25 14:30:00      3056.86  -42.06      TRADE  2022-12-25
# 2178   VIC1 2022-12-16 09:30:00      3632.43  -41.37      TRADE  2022-12-16
# 5279   VIC1 2023-02-19 00:00:00      4476.93  107.54      TRADE  2023-02-19
# 3141   VIC1 2023-01-05 11:00:00      3201.03  -45.00      TRADE  2023-01-05
# 873    VIC1 2022-11-19 05:00:00      3717.42  -19.90      TRADE  2022-11-19
# 5002   VIC1 2023-02-13 05:30:00      4447.54  133.56      TRADE  2023-02-13
# 2515   VIC1 2022-12-23 10:00:00      3917.74  -39.59      TRADE  2022-12-23
# 1926   VIC1 2022-12-11 03:30:00      3729.14    9.20      TRADE  2022-12-11
# 6221   VIC1 2023-03-10 15:00:00      3666.62    9.00      TRADE  2023-03-10
# 7744   VIC1 2023-04-11 08:30:00      5146.68   75.53      TRADE  2023-04-11
# 6886   VIC1 2023-03-24 11:30:00      4166.61    9.00      TRADE  2023-03-24
# 2210   VIC1 2022-12-17 01:30:00      3970.78    8.94      TRADE  2022-12-17
# 3139   VIC1 2023-01-05 10:00:00      3194.69  -55.00      TRADE  2023-01-05
# 2582   VIC1 2022-12-24 19:30:00      4719.81  132.72      TRADE  2022-12-24
# 8160   VIC1 2023-04-20 00:30:00      4667.89  130.11      TRADE  2023-04-20
# 3887   VIC1 2023-01-21 00:00:00      4349.88   79.73      TRADE  2023-01-21
# 5826   VIC1 2023-03-02 09:30:00      4848.93   20.26      TRADE  2023-03-02

# %%
# Calculate maximum daily energy demand and average rrp
max_demand = price_and_demand.groupby("Date")['TOTALDEMAND'].max()
print(type(max_demand))
# Out:
# <class 'pandas.core.series.Series'>

# %%
mean_rrp = price_and_demand.groupby("Date")['RRP'].mean().round(2)
mean_rrp
# Out:
# Date
# 2022-11-01     -3.76
# 2022-11-02     -2.52
# 2022-11-03     63.21
# 2022-11-04    110.94
# 2022-11-05     72.96
#                ...
# 2023-04-20    130.71
# 2023-04-21    131.46
# 2023-04-22     80.39
# 2023-04-23     63.21
# 2023-04-24     63.77
# Name: RRP, Length: 175, dtype: float64

# %%
# Importing Weather Dataset
weather = pd.read_csv("weather.csv", encoding='latin-1',dayfirst = True)
weather
# Out:
#                                Location        Date  Minimum temperature (°C)  \
# 0    Melbourne (Olympic Park), Victoria   1/11/2022                       8.5
# 1    Melbourne (Olympic Park), Victoria   2/11/2022                       6.9
# 2    Melbourne (Olympic Park), Victoria   3/11/2022                       9.1
# 3    Melbourne (Olympic Park), Victoria   4/11/2022                      10.2
# 4    Melbourne (Olympic Park), Victoria   5/11/2022                      11.8
# ..                                  ...         ...                       ...
# 170  Melbourne (Olympic Park), Victoria  20/04/2023                       7.8
# 171  Melbourne (Olympic Park), Victoria  21/04/2023                      11.3
# 172  Melbourne (Olympic Park), Victoria  22/04/2023                      14.6
# 173  Melbourne (Olympic Park), Victoria  23/04/2023                      14.8
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                        13.3            3.0               NaN
# 1                        15.7            2.8               NaN
# 2                        15.4            0.4               NaN
# 3                        17.8            0.2               NaN
# 4                        22.7            0.0               NaN
# ..                        ...            ...               ...
# 170                      18.5            0.0               NaN
# 171                      19.0            0.0               NaN
# 172                      19.2            0.0               NaN
# 173                      19.0            0.0               NaN
# 174                       NaN            0.0               NaN
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 0                 NaN                              SW
# 1                 NaN                             SSW
# 2                 NaN                             SSW
# 3                 NaN                               S
# 4                 NaN                               N
# ..                ...                             ...
# 170               NaN                             SSW
# 171               NaN                             SSW
# 172               NaN                             SSW
# 173               NaN                             SSW
# 174               NaN                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                                 44.0                     11:36  ...
# 1                                 43.0                     11:33  ...
# 2                                 31.0                      8:07  ...
# 3                                 24.0                     14:50  ...
# 4                                 31.0                     11:58  ...
# ..                                 ...                       ...  ...
# 170                               17.0                     12:47  ...
# 171                               13.0                     10:48  ...
# 172                               22.0                     16:09  ...
# 173                               26.0                     15:45  ...
# 174                                NaN                       NaN  ...
#
#      9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                         NaN                  NW                     13
# 1                         NaN                   W                      9
# 2                         NaN                 SSW                      9
# 3                         NaN                 WSW                      6
# 4                         NaN                   N                      9
# ..                        ...                 ...                    ...
# 170                       NaN                 NNE                      7
# 171                       NaN                  NE                      6
# 172                       NaN                  SW                      6
# 173                       NaN                 SSE                      7
# 174                       NaN                  NE                      9
#
#     9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                    991.3                 13.2                       59.0
# 1                   1006.7                 15.1                       54.0
# 2                   1019.2                 13.8                       67.0
# 3                   1028.1                 16.9                       56.0
# 4                   1026.3                 18.8                       65.0
# ..                     ...                  ...                        ...
# 170                 1026.8                 17.5                       58.0
# 171                 1030.5                 18.6                       64.0
# 172                 1031.9                 18.8                       64.0
# 173                 1034.4                 17.8                       71.0
# 174                 1032.5                  NaN                        NaN
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                         NaN                 WNW                   11.0
# 1                         NaN                 SSW                   13.0
# 2                         NaN                 SSW                    9.0
# 3                         NaN                  SW                    9.0
# 4                         NaN                  SW                   11.0
# ..                        ...                 ...                    ...
# 170                       NaN                  SW                    4.0
# 171                       NaN                 SSE                    2.0
# 172                       NaN                 SSW                   11.0
# 173                       NaN                 SSW                   13.0
# 174                       NaN                 NaN                    NaN
#
#     3pm MSL pressure (hPa)
# 0                    991.5
# 1                   1008.4
# 2                   1021.3
# 3                   1026.6
# 4                   1023.2
# ..                     ...
# 170                 1025.5
# 171                 1029.2
# 172                 1029.7
# 173                 1032.4
# 174                    NaN
#
# [175 rows x 22 columns]

# %%
weather.dtypes
# Out:
# Location                              object
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Evaporation (mm)                     float64
# Sunshine (hours)                     float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)              int64
# 9am cloud amount (oktas)             float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)            float64
# 3pm cloud amount (oktas)             float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                float64
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
#Removing entirely empty columns
weather = weather.dropna(axis = 1, how = 'all')
weather
# Out:
#                                Location        Date  Minimum temperature (°C)  \
# 0    Melbourne (Olympic Park), Victoria   1/11/2022                       8.5
# 1    Melbourne (Olympic Park), Victoria   2/11/2022                       6.9
# 2    Melbourne (Olympic Park), Victoria   3/11/2022                       9.1
# 3    Melbourne (Olympic Park), Victoria   4/11/2022                      10.2
# 4    Melbourne (Olympic Park), Victoria   5/11/2022                      11.8
# ..                                  ...         ...                       ...
# 170  Melbourne (Olympic Park), Victoria  20/04/2023                       7.8
# 171  Melbourne (Olympic Park), Victoria  21/04/2023                      11.3
# 172  Melbourne (Olympic Park), Victoria  22/04/2023                      14.6
# 173  Melbourne (Olympic Park), Victoria  23/04/2023                      14.8
# 174  Melbourne (Olympic Park), Victoria  24/04/2023                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm) Direction of maximum wind gust   \
# 0                        13.3            3.0                              SW
# 1                        15.7            2.8                             SSW
# 2                        15.4            0.4                             SSW
# 3                        17.8            0.2                               S
# 4                        22.7            0.0                               N
# ..                        ...            ...                             ...
# 170                      18.5            0.0                             SSW
# 171                      19.0            0.0                             SSW
# 172                      19.2            0.0                             SSW
# 173                      19.0            0.0                             SSW
# 174                       NaN            0.0                             NaN
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 0                                 44.0                     11:36
# 1                                 43.0                     11:33
# 2                                 31.0                      8:07
# 3                                 24.0                     14:50
# 4                                 31.0                     11:58
# ..                                 ...                       ...
# 170                               17.0                     12:47
# 171                               13.0                     10:48
# 172                               22.0                     16:09
# 173                               26.0                     15:45
# 174                                NaN                       NaN
#
#      9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 0                    12.0                         64                 NW
# 1                    11.0                         65                  W
# 2                    11.5                         70                SSW
# 3                    12.3                         84                WSW
# 4                    14.0                         78                  N
# ..                    ...                        ...                ...
# 170                  12.4                         72                NNE
# 171                  14.8                         78                 NE
# 172                  15.2                         84                 SW
# 173                  16.7                         79                SSE
# 174                  14.3                         87                 NE
#
#     9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                      13                   991.3                  13.2
# 1                       9                  1006.7                  15.1
# 2                       9                  1019.2                  13.8
# 3                       6                  1028.1                  16.9
# 4                       9                  1026.3                  18.8
# ..                    ...                     ...                   ...
# 170                     7                  1026.8                  17.5
# 171                     6                  1030.5                  18.6
# 172                     6                  1031.9                  18.8
# 173                     7                  1034.4                  17.8
# 174                     9                  1032.5                   NaN
#
#      3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         59.0                WNW                   11.0
# 1                         54.0                SSW                   13.0
# 2                         67.0                SSW                    9.0
# 3                         56.0                 SW                    9.0
# 4                         65.0                 SW                   11.0
# ..                         ...                ...                    ...
# 170                       58.0                 SW                    4.0
# 171                       64.0                SSE                    2.0
# 172                       64.0                SSW                   11.0
# 173                       71.0                SSW                   13.0
# 174                        NaN                NaN                    NaN
#
#      3pm MSL pressure (hPa)
# 0                     991.5
# 1                    1008.4
# 2                    1021.3
# 3                    1026.6
# 4                    1023.2
# ..                      ...
# 170                  1025.5
# 171                  1029.2
# 172                  1029.7
# 173                  1032.4
# 174                     NaN
#
# [175 rows x 18 columns]

# %%
#Setting Date format to match
weather = weather.copy()
weather["Date"] = pd.to_datetime(weather['Date'], format="%d/%m/%Y")
weather.head()
# Out:
#                              Location       Date  Minimum temperature (°C)  \
# 0  Melbourne (Olympic Park), Victoria 2022-11-01                       8.5
# 1  Melbourne (Olympic Park), Victoria 2022-11-02                       6.9
# 2  Melbourne (Olympic Park), Victoria 2022-11-03                       9.1
# 3  Melbourne (Olympic Park), Victoria 2022-11-04                      10.2
# 4  Melbourne (Olympic Park), Victoria 2022-11-05                      11.8
#
#    Maximum temperature (°C)  Rainfall (mm) Direction of maximum wind gust   \
# 0                      13.3            3.0                              SW
# 1                      15.7            2.8                             SSW
# 2                      15.4            0.4                             SSW
# 3                      17.8            0.2                               S
# 4                      22.7            0.0                               N
#
#    Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 0                               44.0                     11:36
# 1                               43.0                     11:33
# 2                               31.0                      8:07
# 3                               24.0                     14:50
# 4                               31.0                     11:58
#
#    9am Temperature (°C)  9am relative humidity (%) 9am wind direction  \
# 0                  12.0                         64                 NW
# 1                  11.0                         65                  W
# 2                  11.5                         70                SSW
# 3                  12.3                         84                WSW
# 4                  14.0                         78                  N
#
#   9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                    13                   991.3                  13.2
# 1                     9                  1006.7                  15.1
# 2                     9                  1019.2                  13.8
# 3                     6                  1028.1                  16.9
# 4                     9                  1026.3                  18.8
#
#    3pm relative humidity (%) 3pm wind direction  3pm wind speed (km/h)  \
# 0                       59.0                WNW                   11.0
# 1                       54.0                SSW                   13.0
# 2                       67.0                SSW                    9.0
# 3                       56.0                 SW                    9.0
# 4                       65.0                 SW                   11.0
#
#    3pm MSL pressure (hPa)
# 0                   991.5
# 1                  1008.4
# 2                  1021.3
# 3                  1026.6
# 4                  1023.2

# %%
#Setting Date as the ID Column
weather_dateindex = weather.set_index('Date')
weather_dateindex
# Out:
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2022-11-04  Melbourne (Olympic Park), Victoria                      10.2
# 2022-11-05  Melbourne (Olympic Park), Victoria                      11.8
# ...                                        ...                       ...
# 2023-04-20  Melbourne (Olympic Park), Victoria                       7.8
# 2023-04-21  Melbourne (Olympic Park), Victoria                      11.3
# 2023-04-22  Melbourne (Olympic Park), Victoria                      14.6
# 2023-04-23  Melbourne (Olympic Park), Victoria                      14.8
# 2023-04-24  Melbourne (Olympic Park), Victoria                      11.0
#
#             Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                      13.3            3.0
# 2022-11-02                      15.7            2.8
# 2022-11-03                      15.4            0.4
# 2022-11-04                      17.8            0.2
# 2022-11-05                      22.7            0.0
# ...                              ...            ...
# 2023-04-20                      18.5            0.0
# 2023-04-21                      19.0            0.0
# 2023-04-22                      19.2            0.0
# 2023-04-23                      19.0            0.0
# 2023-04-24                       NaN            0.0
#
#            Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# Date
# 2022-11-01                              SW                               44.0
# 2022-11-02                             SSW                               43.0
# 2022-11-03                             SSW                               31.0
# 2022-11-04                               S                               24.0
# 2022-11-05                               N                               31.0
# ...                                    ...                                ...
# 2023-04-20                             SSW                               17.0
# 2023-04-21                             SSW                               13.0
# 2023-04-22                             SSW                               22.0
# 2023-04-23                             SSW                               26.0
# 2023-04-24                             NaN                                NaN
#
#            Time of maximum wind gust  9am Temperature (°C)  \
# Date
# 2022-11-01                     11:36                  12.0
# 2022-11-02                     11:33                  11.0
# 2022-11-03                      8:07                  11.5
# 2022-11-04                     14:50                  12.3
# 2022-11-05                     11:58                  14.0
# ...                              ...                   ...
# 2023-04-20                     12:47                  12.4
# 2023-04-21                     10:48                  14.8
# 2023-04-22                     16:09                  15.2
# 2023-04-23                     15:45                  16.7
# 2023-04-24                       NaN                  14.3
#
#             9am relative humidity (%) 9am wind direction  \
# Date
# 2022-11-01                         64                 NW
# 2022-11-02                         65                  W
# 2022-11-03                         70                SSW
# 2022-11-04                         84                WSW
# 2022-11-05                         78                  N
# ...                               ...                ...
# 2023-04-20                         72                NNE
# 2023-04-21                         78                 NE
# 2023-04-22                         84                 SW
# 2023-04-23                         79                SSE
# 2023-04-24                         87                 NE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                    13                   991.3
# 2022-11-02                     9                  1006.7
# 2022-11-03                     9                  1019.2
# 2022-11-04                     6                  1028.1
# 2022-11-05                     9                  1026.3
# ...                          ...                     ...
# 2023-04-20                     7                  1026.8
# 2023-04-21                     6                  1030.5
# 2023-04-22                     6                  1031.9
# 2023-04-23                     7                  1034.4
# 2023-04-24                     9                  1032.5
#
#             3pm Temperature (°C)  3pm relative humidity (%)  \
# Date
# 2022-11-01                  13.2                       59.0
# 2022-11-02                  15.1                       54.0
# 2022-11-03                  13.8                       67.0
# 2022-11-04                  16.9                       56.0
# 2022-11-05                  18.8                       65.0
# ...                          ...                        ...
# 2023-04-20                  17.5                       58.0
# 2023-04-21                  18.6                       64.0
# 2023-04-22                  18.8                       64.0
# 2023-04-23                  17.8                       71.0
# 2023-04-24                   NaN                        NaN
#
#            3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                WNW                   11.0                   991.5
# 2022-11-02                SSW                   13.0                  1008.4
# 2022-11-03                SSW                    9.0                  1021.3
# 2022-11-04                 SW                    9.0                  1026.6
# 2022-11-05                 SW                   11.0                  1023.2
# ...                       ...                    ...                     ...
# 2023-04-20                 SW                    4.0                  1025.5
# 2023-04-21                SSE                    2.0                  1029.2
# 2023-04-22                SSW                   11.0                  1029.7
# 2023-04-23                SSW                   13.0                  1032.4
# 2023-04-24                NaN                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
"""Data Cleaning across entire dataframe"""
#Replacing all occurrences of 'Calm' windspeed with 0 km/h
weather_nocalm = weather_dateindex.replace("Calm",0)
weather_nocalm
# Out:
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2023-04-22                  18.8                       64.0
# 2023-04-23                  17.8                       71.0
# 2023-04-24                   NaN                        NaN
#
#            3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                WNW                   11.0                   991.5
# 2022-11-02                SSW                   13.0                  1008.4
# 2022-11-03                SSW                    9.0                  1021.3
# 2022-11-04                 SW                    9.0                  1026.6
# 2022-11-05                 SW                   11.0                  1023.2
# ...                       ...                    ...                     ...
# 2023-04-20                 SW                    4.0                  1025.5
# 2023-04-21                SSE                    2.0                  1029.2
# 2023-04-22                SSW                   11.0                  1029.7
# 2023-04-23                SSW                   13.0                  1032.4
# 2023-04-24                NaN                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
#Replacing all wind directions with True Bearing quantities
weather_bearings = weather_nocalm.replace(['N','NNE','NE','ENE','E','ESE','SE','SSE','S','SSW','SW','WSW','W','WNW','NW','NNW'],
                                          [0,22.5,45,67.5,90,112.5,135,157.5,180,202.5,225,247.5,270,292.5,315,337.5])
#Renaming Columns with True Bearing Units
weather_bearings.rename(columns = {'Direction of maximum wind gust ':'Direction of maximum wind gust (°T)', '9am wind direction':'9am wind direction (°T)','3pm wind direction':'3pm wind direction (°T)'},inplace = True)

#Data Cleaning Complete
processed_data = weather_bearings

processed_data
# Out:
#                                       Location  Minimum temperature (°C)  \
# Date
# 2022-11-01  Melbourne (Olympic Park), Victoria                       8.5
# 2022-11-02  Melbourne (Olympic Park), Victoria                       6.9
# 2022-11-03  Melbourne (Olympic Park), Victoria                       9.1
# 2022-11-04  Melbourne (Olympic Park), Victoria                      10.2
# 2022-11-05  Melbourne (Olympic Park), Victoria                      11.8
# ...                                        ...                       ...
# 2023-04-20  Melbourne (Olympic Park), Victoria                       7.8
# 2023-04-21  Melbourne (Olympic Park), Victoria                      11.3
# 2023-04-22  Melbourne (Olympic Park), Victoria                      14.6
# 2023-04-23  Melbourne (Olympic Park), Victoria                      14.8
# 2023-04-24  Melbourne (Olympic Park), Victoria                      11.0
#
#             Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                      13.3            3.0
# 2022-11-02                      15.7            2.8
# 2022-11-03                      15.4            0.4
# 2022-11-04                      17.8            0.2
# 2022-11-05                      22.7            0.0
# ...                              ...            ...
# 2023-04-20                      18.5            0.0
# 2023-04-21                      19.0            0.0
# 2023-04-22                      19.2            0.0
# 2023-04-23                      19.0            0.0
# 2023-04-24                       NaN            0.0
#
#             Direction of maximum wind gust (°T)  \
# Date
# 2022-11-01                                225.0
# 2022-11-02                                202.5
# 2022-11-03                                202.5
# 2022-11-04                                180.0
# 2022-11-05                                  0.0
# ...                                         ...
# 2023-04-20                                202.5
# 2023-04-21                                202.5
# 2023-04-22                                202.5
# 2023-04-23                                202.5
# 2023-04-24                                  NaN
#
#             Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# Date
# 2022-11-01                               44.0                     11:36
# 2022-11-02                               43.0                     11:33
# 2022-11-03                               31.0                      8:07
# 2022-11-04                               24.0                     14:50
# 2022-11-05                               31.0                     11:58
# ...                                       ...                       ...
# 2023-04-20                               17.0                     12:47
# 2023-04-21                               13.0                     10:48
# 2023-04-22                               22.0                     16:09
# 2023-04-23                               26.0                     15:45
# 2023-04-24                                NaN                       NaN
#
#             9am Temperature (°C)  9am relative humidity (%)  \
# Date
# 2022-11-01                  12.0                         64
# 2022-11-02                  11.0                         65
# 2022-11-03                  11.5                         70
# 2022-11-04                  12.3                         84
# 2022-11-05                  14.0                         78
# ...                          ...                        ...
# 2023-04-20                  12.4                         72
# 2023-04-21                  14.8                         78
# 2023-04-22                  15.2                         84
# 2023-04-23                  16.7                         79
# 2023-04-24                  14.3                         87
#
#            9am wind direction (°T) 9am wind speed (km/h)  \
# Date
# 2022-11-01                     315                    13
# 2022-11-02                     270                     9
# 2022-11-03                   202.5                     9
# 2022-11-04                   247.5                     6
# 2022-11-05                       0                     9
# ...                            ...                   ...
# 2023-04-20                    22.5                     7
# 2023-04-21                      45                     6
# 2023-04-22                     225                     6
# 2023-04-23                   157.5                     7
# 2023-04-24                      45                     9
#
#             9am MSL pressure (hPa)  3pm Temperature (°C)  \
# Date
# 2022-11-01                   991.3                  13.2
# 2022-11-02                  1006.7                  15.1
# 2022-11-03                  1019.2                  13.8
# 2022-11-04                  1028.1                  16.9
# 2022-11-05                  1026.3                  18.8
# ...                            ...                   ...
# 2023-04-20                  1026.8                  17.5
# 2023-04-21                  1030.5                  18.6
# 2023-04-22                  1031.9                  18.8
# 2023-04-23                  1034.4                  17.8
# 2023-04-24                  1032.5                   NaN
#
#             3pm relative humidity (%)  3pm wind direction (°T)  \
# Date
# 2022-11-01                       59.0                    292.5
# 2022-11-02                       54.0                    202.5
# 2022-11-03                       67.0                    202.5
# 2022-11-04                       56.0                    225.0
# 2022-11-05                       65.0                    225.0
# ...                               ...                      ...
# 2023-04-20                       58.0                    225.0
# 2023-04-21                       64.0                    157.5
# 2023-04-22                       64.0                    202.5
# 2023-04-23                       71.0                    202.5
# 2023-04-24                        NaN                      NaN
#
#             3pm wind speed (km/h)  3pm MSL pressure (hPa)
# Date
# 2022-11-01                   11.0                   991.5
# 2022-11-02                   13.0                  1008.4
# 2022-11-03                    9.0                  1021.3
# 2022-11-04                    9.0                  1026.6
# 2022-11-05                   11.0                  1023.2
# ...                           ...                     ...
# 2023-04-20                    4.0                  1025.5
# 2023-04-21                    2.0                  1029.2
# 2023-04-22                   11.0                  1029.7
# 2023-04-23                   13.0                  1032.4
# 2023-04-24                    NaN                     NaN
#
# [175 rows x 17 columns]

# %%
#Selecting key features based on 'expert' insight and desired focus variables
selected_features = ["Minimum temperature (°C)", "Maximum temperature (°C)", "Rainfall (mm)","Speed of maximum wind gust (km/h)","9am relative humidity (%)","3pm relative humidity (%)", "9am wind speed (km/h)","3pm wind speed (km/h)", "9am MSL pressure (hPa)", "3pm MSL pressure (hPa)"]
# selected_features = ["Maximum temperature (°C)", "3pm relative humidity (%)"]
selected_features

selected_data = processed_data[selected_features]

#Checking for missing values across selected features
missing_value = processed_data[selected_features].isnull()
missing_value

#Removing data points with missing selected features
selected_data = processed_data[selected_features].dropna()
predictor_data = processed_data[selected_features].dropna()
predictor_data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 2023-04-19                      14.4                      17.5            1.2
# 2023-04-20                       7.8                      18.5            0.0
# 2023-04-21                      11.3                      19.0            0.0
# 2023-04-22                      14.6                      19.2            0.0
# 2023-04-23                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2022-11-01                               44.0                         64
# 2022-11-02                               43.0                         65
# 2022-11-03                               31.0                         70
# 2022-11-04                               24.0                         84
# 2022-11-05                               31.0                         78
# ...                                       ...                        ...
# 2023-04-19                               28.0                         66
# 2023-04-20                               17.0                         72
# 2023-04-21                               13.0                         78
# 2023-04-22                               22.0                         84
# 2023-04-23                               26.0                         79
#
#             3pm relative humidity (%) 9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                    13
# 2022-11-02                       54.0                     9
# 2022-11-03                       67.0                     9
# 2022-11-04                       56.0                     6
# 2022-11-05                       65.0                     9
# ...                               ...                   ...
# 2023-04-19                       53.0                     9
# 2023-04-20                       58.0                     7
# 2023-04-21                       64.0                     6
# 2023-04-22                       64.0                     6
# 2023-04-23                       71.0                     7
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
# ...                           ...                     ...
# 2023-04-19                    9.0                  1022.0
# 2023-04-20                    4.0                  1026.8
# 2023-04-21                    2.0                  1030.5
# 2023-04-22                   11.0                  1031.9
# 2023-04-23                   13.0                  1034.4
#
#             3pm MSL pressure (hPa)
# Date
# 2022-11-01                   991.5
# 2022-11-02                  1008.4
# 2022-11-03                  1021.3
# 2022-11-04                  1026.6
# 2022-11-05                  1023.2
# ...                            ...
# 2023-04-19                  1022.1
# 2023-04-20                  1025.5
# 2023-04-21                  1029.2
# 2023-04-22                  1029.7
# 2023-04-23                  1032.4
#
# [174 rows x 10 columns]

# %%
# Converting all data to float64
selected_data = selected_data.astype(float)
selected_data

predictor_data = predictor_data.astype(float)
predictor_data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 2023-04-19                      14.4                      17.5            1.2
# 2023-04-20                       7.8                      18.5            0.0
# 2023-04-21                      11.3                      19.0            0.0
# 2023-04-23                               26.0                       79.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   13.0
# 2022-11-02                       54.0                    9.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    6.0
# 2022-11-05                       65.0                    9.0
# ...                               ...                    ...
# 2023-04-19                       53.0                    9.0
# 2023-04-20                       58.0                    7.0
# 2023-04-21                       64.0                    6.0
# 2023-04-22                       64.0                    6.0
# 2023-04-23                       71.0                    7.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
# ...                           ...                     ...
# 2023-04-19                    9.0                  1022.0
# 2023-04-20                    4.0                  1026.8
# 2023-04-21                    2.0                  1030.5
# 2023-04-22                   11.0                  1031.9
# 2023-04-23                   13.0                  1034.4
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
# ...                            ...          ...                    ...
# 2023-04-19                  1022.1       102.33                6042.88
# 2023-04-20                  1025.5       130.71                6084.21
# 2023-04-21                  1029.2       131.46                5903.60
# 2023-04-22                  1029.7        80.39                5313.61
# 2023-04-23                  1032.4        63.21                5361.47
#
# [174 rows x 12 columns]

# %% [markdown]
# ## KNN Modelling

# %%
# checking distribution of max energy demand
selected_data["Maximum Energy Demand"].hist(color="brown")

plt.title("Distribution of max energy demand before binning")

plt.show()

# %% [markdown]
# ### KNN with 3 bins

# %%
# Categorise energy demand into 3 bins

def bin_energy(x):

    LOWER = 6000
    UPPER = 7000
    
    # [min, 6000)
    if x < LOWER:
        return 0
    # [6000, 7000)
    elif LOWER <= x < UPPER:
        return 1 
    # [7000, max] 
    return 2

# apply the function on the serie
selected_data.insert(loc = 12, column = "3 bin energy", value = selected_data["Maximum Energy Demand"].apply(bin_energy))

selected_data
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
# ...                              ...                       ...            ...
# 2023-04-19                      14.4                      17.5            1.2
# 2023-04-20                       7.8                      18.5            0.0
# 2023-04-21                      11.3                      19.0            0.0
# 2023-04-22                      14.6                      19.2            0.0
# 2023-04-23                      14.8                      19.0            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2022-11-01                               44.0                       64.0
# 2022-11-02                               43.0                       65.0
# 2022-11-03                               31.0                       70.0
# 2022-11-04                               24.0                       84.0
# 2022-11-05                               31.0                       78.0
# ...                                       ...                        ...
# 2023-04-19                               28.0                       66.0
# 2023-04-20                               17.0                       72.0
# 2023-04-21                               13.0                       78.0
# 2023-04-22                               22.0                       84.0
# 2023-04-23                               26.0                       79.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   13.0
# 2022-11-02                       54.0                    9.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    6.0
# 2022-11-05                       65.0                    9.0
# ...                               ...                    ...
# 2023-04-19                       53.0                    9.0
# 2023-04-20                       58.0                    7.0
# 2023-04-21                       64.0                    6.0
# 2023-04-22                       64.0                    6.0
# 2023-04-23                       71.0                    7.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
# ...                           ...                     ...
# 2023-04-19                    9.0                  1022.0
# 2023-04-20                    4.0                  1026.8
# 2023-04-21                    2.0                  1030.5
# 2023-04-22                   11.0                  1031.9
# 2023-04-23                   13.0                  1034.4
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand  \
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
# ...                            ...          ...                    ...
# 2023-04-19                  1022.1       102.33                6042.88
# 2023-04-20                  1025.5       130.71                6084.21
# 2023-04-21                  1029.2       131.46                5903.60
# 2023-04-22                  1029.7        80.39                5313.61
# 2023-04-23                  1032.4        63.21                5361.47
#
#             3 bin energy
# Date
# 2022-11-01             0
# 2022-11-02             1
# 2022-11-03             1
# 2022-11-04             0
# 2022-11-05             0
# ...                  ...
# 2023-04-19             1
# 2023-04-20             1
# 2023-04-21             0
# 2023-04-22             0
# 2023-04-23             0
#
# [174 rows x 13 columns]

# %%
# check and compare energy distribution before & after binning

selected_data["Maximum Energy Demand"].hist(color="brown")

plt.title("Distribution of max energy demand before binning")

plt.show()

selected_data["3 bin energy"].hist(color = "brown")

plt.title('Distribution of daily energy demand after binning')

plt.show()

# %%
""" KNN with all variables and target feature """

from sklearn import neighbors
from sklearn import preprocessing
from sklearn.metrics import accuracy_score

display(selected_data.head())

features = predictor_data
classlabel = selected_data["3 bin energy"]

#Splitting data to train and test sets 
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=42)

#Scalling
scaler = preprocessing.StandardScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

#Fit
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(features_train, class_train)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2022-11-01                               44.0                       64.0
# 2022-11-02                               43.0                       65.0
# 2022-11-03                               31.0                       70.0
# 2022-11-04                               24.0                       84.0
# 2022-11-05                               31.0                       78.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   13.0
# 2022-11-02                       54.0                    9.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    6.0
# 2022-11-05                       65.0                    9.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand  \
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
#
#             3 bin energy
# Date
# 2022-11-01             0
# 2022-11-02             1
# 2022-11-03             1
# 2022-11-04             0
# 2022-11-05             0
# KNeighborsClassifier()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
predictions = knn.predict(features_test)
print(accuracy_score(class_test, predictions))
# Out:
# 0.8571428571428571

# %%
""" Using K-fold to cross-validate and to assess the performance and generalization ability of a model."""

from sklearn.model_selection import KFold


features = predictor_data
classlabel = selected_data["3 bin energy"]


k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)
accuracy_scores = []

for train_index, test_index in kf.split(selected_data):
    features_train = features.iloc[train_index, :]
    features_test = features.iloc[test_index, :]
    
    class_train = classlabel[train_index]
    class_test = classlabel[test_index]
    
    scaler = preprocessing.StandardScaler().fit(features_train)
    features_train = scaler.transform(features_train)
    features_test = scaler.transform(features_test)
    
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    knn.fit(features_train, class_train)
    
    predictions = knn.predict(features_test)
    accuracy_scores.append(accuracy_score(class_test, predictions))
    
print(accuracy_scores)
print(sum(accuracy_scores)/k)
# Out:
# [0.7777777777777778, 0.9444444444444444, 0.8333333333333334, 0.7777777777777778, 0.8823529411764706, 0.7647058823529411, 0.8235294117647058, 0.7647058823529411, 0.7058823529411765, 0.7647058823529411]
# 0.803921568627451

# %% [markdown]
# ### KNN with 4 bins

# %%
# Categorize max energy demand into 4 bins


def bin_energy_4(x):
    
    LOWER = 4900
    MIDIAN = 5800
    UPPER = 6600
    
    # [min, 4900)
    if x < LOWER:
        return 0
    # [4900, 5800)
    elif LOWER <= x < MIDIAN:
        return 1
    # [5800, 6600)
    elif MIDIAN <= x < UPPER:
        return 2 
    # [6600, max] 
    return 3

# apply the function on the serie
selected_data.insert(loc = 13, column = "4 bin energy", value = selected_data["Maximum Energy Demand"].apply(bin_energy_4))
selected_data.head()
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2022-11-01                               44.0                       64.0
# 2022-11-02                               43.0                       65.0
# 2022-11-03                               31.0                       70.0
# 2022-11-04                               24.0                       84.0
# 2022-11-05                               31.0                       78.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   13.0
# 2022-11-02                       54.0                    9.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    6.0
# 2022-11-05                       65.0                    9.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand  \
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
#
#             3 bin energy  4 bin energy
# Date
# 2022-11-01             0             1
# 2022-11-02             1             2
# 2022-11-03             1             2
# 2022-11-04             0             1
# 2022-11-05             0             0

# %%
# check and compare energy distribution before & after binning

selected_data["Maximum Energy Demand"].hist(color="brown")

plt.title("Distribution of max energy demand before binning")

plt.show()

selected_data['4 bin energy'].hist(color = "brown")

plt.title('Distribution of daily energy demand after binning')

plt.show()

# %%
""" KNN with all variables and target feature """

from sklearn import neighbors
from sklearn import preprocessing
from sklearn.metrics import accuracy_score

display(selected_data.head())

features = predictor_data
classlabel = selected_data["4 bin energy"]

#Splitting data to train and test sets 
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=42)

#Scalling
scaler = preprocessing.StandardScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

#Fit
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(features_train, class_train)
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2022-11-01                       8.5                      13.3            3.0
# 2022-11-02                       6.9                      15.7            2.8
# 2022-11-03                       9.1                      15.4            0.4
# 2022-11-04                      10.2                      17.8            0.2
# 2022-11-05                      11.8                      22.7            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2022-11-01                               44.0                       64.0
# 2022-11-02                               43.0                       65.0
# 2022-11-03                               31.0                       70.0
# 2022-11-04                               24.0                       84.0
# 2022-11-05                               31.0                       78.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2022-11-01                       59.0                   13.0
# 2022-11-02                       54.0                    9.0
# 2022-11-03                       67.0                    9.0
# 2022-11-04                       56.0                    6.0
# 2022-11-05                       65.0                    9.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2022-11-01                   11.0                   991.3
# 2022-11-02                   13.0                  1006.7
# 2022-11-03                    9.0                  1019.2
# 2022-11-04                    9.0                  1028.1
# 2022-11-05                   11.0                  1026.3
#
#             3pm MSL pressure (hPa)  Average RRP  Maximum Energy Demand  \
# Date
# 2022-11-01                   991.5        -3.76                5627.52
# 2022-11-02                  1008.4        -2.52                6018.43
# 2022-11-03                  1021.3        63.21                6004.84
# 2022-11-04                  1026.6       110.94                5757.62
# 2022-11-05                  1023.2        72.96                4783.60
#
#             3 bin energy  4 bin energy
# Date
# 2022-11-01             0             1
# 2022-11-02             1             2
# 2022-11-03             1             2
# 2022-11-04             0             1
# 2022-11-05             0             0
# KNeighborsClassifier()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
predictions = knn.predict(features_test)
print(accuracy_score(class_test, predictions))
# Out:
# 0.6571428571428571

# %%
""" Using K-fold to cross-validate and to assess the performance and generalization ability of a model."""

from sklearn.model_selection import KFold


features = predictor_data
classlabel = selected_data["4 bin energy"]


k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)
accuracy_scores = []

for train_index, test_index in kf.split(selected_data):
    features_train = features.iloc[train_index, :]
    features_test = features.iloc[test_index, :]
    
    class_train = classlabel[train_index]
    class_test = classlabel[test_index]
    
    scaler = preprocessing.StandardScaler().fit(features_train)
    features_train = scaler.transform(features_train)
    features_test = scaler.transform(features_test)
    
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    knn.fit(features_train, class_train)
    
    predictions = knn.predict(features_test)
    accuracy_scores.append(accuracy_score(class_test, predictions))
    
print(accuracy_scores)
print(sum(accuracy_scores)/k)
# Out:
# [0.6111111111111112, 0.6666666666666666, 0.6666666666666666, 0.6111111111111112, 0.5882352941176471, 0.5882352941176471, 0.47058823529411764, 0.4117647058823529, 0.7058823529411765, 0.5882352941176471]
# 0.5908496732026144

# %% [markdown]
# ### Selecting features with Chi2 feature selection method

# %%
""" KNN chi2 feature selection with all variables and target feature with 3 bins"""

from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, chi2
import numpy as np

# Extracting features and class labels
features = predictor_data
classlabel = selected_data["3 bin energy"]

# Splitting data into train and test sets
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=42)

# Instantiate feature selector
feature_selector = SelectKBest(chi2, k=10)

# Perform selection on the training set
features_train_selected = feature_selector.fit_transform(features_train, class_train)

# Perform selection on the test set
features_test_selected = feature_selector.transform(features_test)

# Display selected features
print("Selected Features:")
display(features_train.columns[feature_selector.get_support()])

# Scaling
scaler = preprocessing.StandardScaler()

# Fit the scaler on the selected training features
scaler.fit(features_train_selected)

# Transform the training and test features using the fitted scaler
features_train_scaled = scaler.transform(features_train_selected)
features_test_scaled = scaler.transform(features_test_selected)

# Fit KNN classifier
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(features_train_scaled, class_train)

# Make predictions
predictions = knn.predict(features_test_scaled)

# Print accuracy score
accuracy = accuracy_score(class_test, predictions)
print("Accuracy Score:", accuracy)

# Dictionary to store k values and corresponding accuracy scores
accuracy_dict = {}

# Adjust k value in feature_selector to output all k values and corresponding accuracy scores
k_values = range(1, 11)
for k in k_values:
    feature_selector = SelectKBest(chi2, k=k)
    features_train_selected = feature_selector.fit_transform(features_train, class_train)
    features_test_selected = feature_selector.transform(features_test)
    
    # Fit the scaler on the selected training features
    scaler.fit(features_train_selected)

    # Transform the training and test features using the fitted scaler
    features_train_scaled = scaler.transform(features_train_selected)
    features_test_scaled = scaler.transform(features_test_selected)
    
    knn.fit(features_train_scaled, class_train)
    predictions = knn.predict(features_test_scaled)
    # Calculate and store accuracy score in the dictionary
    accuracy_dict[k] = accuracy_score(class_test, predictions)

# Print the dictionary containing k values and accuracy scores
print("\nAccuracy Scores for Different k Values:")
print(accuracy_dict)
# Out:
# Selected Features:
# Index(['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)',
#        'Speed of maximum wind gust (km/h)', '9am relative humidity (%)',
#        '3pm relative humidity (%)', '9am wind speed (km/h)',
#        '3pm wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm MSL pressure (hPa)'],
#       dtype='object')
# Accuracy Score: 0.8571428571428571
#
# Accuracy Scores for Different k Values:
# {1: 0.8571428571428571, 2: 0.8571428571428571, 3: 0.8571428571428571, 4: 0.8285714285714286, 5: 0.8285714285714286, 6: 0.8285714285714286, 7: 0.8571428571428571, 8: 0.8571428571428571, 9: 0.8285714285714286, 10: 0.8571428571428571}

# %%
# Plot accuracy score of each feature against the number of top performing feature selected

plt.scatter(accuracy_dict.keys(),accuracy_dict.values(), color = 'blue')
plt.title('KNN Modeling of Energy Demand')
plt.xlabel('Number of top performing features')
plt.ylabel('Accuracy Score')
plt.show()

# %%
""" KNN feature selection -- k=7"""

# ML workflow WITH filter-based FS
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, mutual_info_regression


#display(selected_data.head())

features = predictor_data
classlabel = selected_data["3 bin energy"]

#Splitting data to train and test sets 
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=42)
display(features_train.head())

# Instantiate
feature_selector = SelectKBest(chi2, k=7)
# Perform selection
features_train = feature_selector.fit_transform(features_train, class_train)
features_test = feature_selector.transform(features_test)
display(features_train)

#Scalling
scaler = preprocessing.StandardScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

#Fit
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(features_train, class_train)

predictions = knn.predict(features_test)
print(accuracy_score(class_test, predictions))
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2023-02-27                      16.3                      20.2            2.6
# 2023-03-23                      15.3                      22.6           10.2
# 2023-04-13                      11.2                      22.8            4.4
features = selected_data[["Maximum temperature (°C)","Rainfall (mm)", "Speed of maximum wind gust (km/h)", "9am relative humidity (%)", "3pm relative humidity (%)", "9am wind speed (km/h)", "3pm wind speed (km/h)" ]]
classlabel = selected_data["3 bin energy"]


k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)
accuracy_scores = []

for train_index, test_index in kf.split(selected_data):
    features_train = features.iloc[train_index, :]
    features_test = features.iloc[test_index, :]
    
    class_train = classlabel[train_index]
    class_test = classlabel[test_index]
    
    scaler = preprocessing.StandardScaler().fit(features_train)
    features_train = scaler.transform(features_train)
    features_test = scaler.transform(features_test)
    
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    knn.fit(features_train, class_train)
    
    predictions = knn.predict(features_test)
    accuracy_scores.append(accuracy_score(class_test, predictions))
    
print(accuracy_scores)
print(sum(accuracy_scores)/k)
# Out:
# [0.7777777777777778, 0.8888888888888888, 0.8333333333333334, 0.7777777777777778, 0.8823529411764706, 0.6470588235294118, 0.8235294117647058, 0.7647058823529411, 0.8823529411764706, 0.7647058823529411]
# 0.8042483660130717

# %%
""" KNN feature selection -- k=3"""

# ML workflow WITH filter-based FS
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, mutual_info_regression


#display(selected_data.head())

features = predictor_data
classlabel = selected_data["3 bin energy"]

#Splitting data to train and test sets 
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=42)
display(features_train.head())

# Instantiate
feature_selector = SelectKBest(chi2, k=3)
# Perform selection
features_train = feature_selector.fit_transform(features_train, class_train)
features_test = feature_selector.transform(features_test)
display(features_train)

#Scalling
scaler = preprocessing.StandardScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

#Fit
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(features_train, class_train)

predictions = knn.predict(features_test)
print(accuracy_score(class_test, predictions))
# Out:
#             Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 2023-02-27                      16.3                      20.2            2.6
# 2023-03-23                      15.3                      22.6           10.2
# 2023-04-13                      11.2                      22.8            4.4
# 2022-12-09                       9.9                      17.6            2.4
# 2023-03-20                      14.9                      20.8            0.0
#
#             Speed of maximum wind gust (km/h)  9am relative humidity (%)  \
# Date
# 2023-02-27                               33.0                       77.0
# 2023-03-23                               24.0                      100.0
# 2023-04-13                               28.0                       89.0
# 2022-12-09                               41.0                       44.0
# 2023-03-20                               41.0                       56.0
#
#             3pm relative humidity (%)  9am wind speed (km/h)  \
# Date
# 2023-02-27                       72.0                   13.0
# 2023-03-23                       68.0                    9.0
# 2023-04-13                       52.0                    4.0
# 2022-12-09                       51.0                   15.0
# 2023-03-20                       42.0                   17.0
#
#             3pm wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 2023-02-27                   11.0                  1015.4
# 2023-03-23                    9.0                  1017.6
# 2023-04-13                   11.0                  1015.7
# 2022-12-09                   17.0                  1018.1
# 2023-03-20                   15.0                  1027.8
#
#             3pm MSL pressure (hPa)
# Date
# 2023-02-27                  1015.9
# 2023-03-23                  1015.6
# 2023-04-13                  1015.2
# 2022-12-09                  1017.3
# 2023-03-20                  1026.5
# array([[20.2,  2.6, 72. ],
#        [22.6, 10.2, 68. ],
#        [22.8,  4.4, 52. ],
#        [17.6,  2.4, 51. ],
#        [20.8,  0. , 42. ],
#        [20.9,  0. , 55. ],
#        [30.2,  0. , 34. ],
#        [20.9,  8. , 69. ],
#        [15.4,  0.4, 67. ],
#        [20.4,  0. , 60. ],
#        [15.2, 14.8, 64. ],
#        [18.5,  5.8, 60. ],
#        [20.6,  0. , 58. ],
#        [40.5,  0. , 16. ],
#        [20.5,  0.2, 51. ],
#        [19.4,  0. , 67. ],
#        [21.7,  0. , 63. ],
#        [32.3,  0. , 30. ],
#        [26.2,  0. , 75. ],
#        [19.3,  0.2, 62. ],
#        [30. ,  1.8, 50. ],
#        [17.7,  0.6, 77. ],
#        [21.6,  1.4, 55. ],
#        [19.8,  1.2, 59. ],
#        [31.9,  0. , 28. ],
#        [20.7,  2. , 57. ],
#        [19.3,  0. , 66. ],
#        [20.9,  0. , 60. ],
#        [27. ,  0. , 50. ],
#        [25.9,  0. , 66. ],
#        [18.8,  0.2, 46. ],
#        [23.4,  0. , 70. ],
#        [22.7,  0. , 65. ],
#        [31. ,  0. , 42. ],
#        [21.3,  0.2, 39. ],
#        [21.1,  3.2, 61. ],
#        [21.2,  0. , 69. ],
#        [20.2,  3. , 81. ],
#        [18.5,  0. , 58. ],
#        [19.8,  0.2, 54. ],
#        [13.3,  3. , 59. ],
#        [28.5,  0. , 40. ],
#        [32.9,  0. , 31. ],
#        [18.7,  0. , 76. ],
#        [16.6,  3.4, 57. ],
#        [20.7,  6.6, 58. ],
#        [18.4,  0.4, 52. ],
#        [28.6,  0. , 35. ],
#        [25.3,  5.6, 37. ],
#        [27.3,  0. , 33. ],
#        [19.2,  2.8, 63. ],
#        [22.6,  0. , 63. ],
#        [23. ,  0. , 66. ],
#        [19.3,  4.6, 53. ],
#        [28.6,  0. , 36. ],
#        [25.9,  0. , 32. ],
#        [26.4,  0.2, 56. ],
#        [21.6,  0. , 56. ],
#        [17.6,  0.2, 97. ],
#        [17.5,  1.2, 53. ],
#        [18.3,  0. , 81. ],
#        [23.7,  0. , 41. ],
#        [18.8, 11.2, 44. ],
#        [22.4,  0. , 55. ],
#        [19.3,  7. , 64. ],
#        [35.9,  0. , 34. ],
#        [24.2,  0. , 70. ],
#        [34.5,  0. , 28. ],
#        [31.4,  0. , 36. ],
#        [22.8,  1.6, 65. ],
#        [24.6,  2.6, 41. ],
#        [32. ,  6.4, 80. ],
#        [19.2,  0. , 64. ],
#        [24. ,  0. , 60. ],
#        [32.4,  0. , 32. ],
#        [22.2,  0. , 52. ],
#        [23.5,  0. , 53. ],
#        [27.1,  0. , 33. ],
#        [26.3,  0. , 40. ],
#        [17.8,  0.2, 56. ],
#        [19.1,  6. , 61. ],
#        [27.3,  0. , 32. ],
#        [20. ,  1.2, 56. ],
#        [21. ,  0. , 49. ],
#        [37.2,  0. , 31. ],
#        [18.1,  0. , 70. ],
#        [22.3,  0.2, 44. ],
#        [27.6,  0. , 43. ],
#        [15.8,  6.2, 77. ],
#        [21.6,  0. , 63. ],
#        [30.5,  0. , 34. ],
#        [27.9,  0. , 35. ],
#        [22.2,  0. , 51. ],
#        [28. ,  0. , 46. ],
#        [19.9,  4.4, 62. ],
#        [23.8,  0.2, 77. ],
#        [29.3,  2.8, 37. ],
#        [17.4, 13.6, 87. ],
#        [26.2,  0. , 52. ],
#        [18. , 11.2, 76. ],
#        [20.7,  0. , 58. ],
#        [24.5,  0. , 47. ],
#        [24. ,  0. , 73. ],
#        [18.3,  0.2, 54. ],
#        [22.9,  0. , 69. ],
#        [19.9,  0. , 63. ],
#        [15.5,  7.8, 60. ],
#        [21.1,  0.2, 58. ],
#        [31.9,  0. , 31. ],
#        [37.2,  0. , 24. ],
#        [29.4,  0. , 27. ],
#        [19. ,  0. , 64. ],
#        [19.3,  0.8, 55. ],
#        [26. ,  0. , 39. ],
#        [34.2,  0. , 18. ],
#        [18.2,  2. , 58. ],
#        [27.6,  0. , 71. ],
#        [22.8,  0. , 48. ],
#        [24. ,  0. , 51. ],
#        [16. ,  0.6, 48. ],
#        [25.4,  0. , 44. ],
#        [15.7,  2.8, 54. ],
#        [23.1,  1.6, 76. ],
#        [19.1,  8.2, 57. ],
#        [24.7,  0. , 47. ],
#        [16.4,  4.6, 62. ],
#        [20.7,  0. , 47. ],
#        [22.2,  0. , 64. ],
#        [26.7,  0. , 43. ],
#        [26.8,  0. , 45. ],
#        [37.6,  0. , 26. ],
#        [21.7,  0.8, 59. ],
#        [19. ,  0. , 71. ],
#        [13.8,  1.2, 64. ],
#        [29.9,  0. , 49. ],
#        [32.4,  0. , 31. ],
#        [13.1, 14.2, 72. ],
#        [21. ,  0. , 65. ],
#        [25.7,  0. , 65. ]])
# 0.8571428571428571

# %%
""" Using K-fold to cross-validate the performance of selected 3 predictors"""

from sklearn.model_selection import KFold


features = selected_data[["Maximum temperature (°C)","Rainfall (mm)", "3pm relative humidity (%)"]]
classlabel = selected_data["3 bin energy"]


k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)
accuracy_scores = []

for train_index, test_index in kf.split(selected_data):
    features_train = features.iloc[train_index, :]
    features_test = features.iloc[test_index, :]
    
    class_train = classlabel[train_index]
    class_test = classlabel[test_index]
    
    scaler = preprocessing.StandardScaler().fit(features_train)
    features_train = scaler.transform(features_train)
    features_test = scaler.transform(features_test)
    
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    knn.fit(features_train, class_train)
    
    predictions = knn.predict(features_test)
    accuracy_scores.append(accuracy_score(class_test, predictions))
    
print(accuracy_scores)
print(sum(accuracy_scores)/k)
# Out:
# [0.7777777777777778, 0.9444444444444444, 0.8333333333333334, 0.7222222222222222, 0.9411764705882353, 0.8823529411764706, 0.8823529411764706, 0.7647058823529411, 0.8823529411764706, 0.8235294117647058]
# 0.8454248366013072
